# %%
import facebook
graph = facebook.GraphAPI("CAACEdEose0cBADcatqYJalWMhs6ZAfY1dHx7dTfhTSFno7tgxUoSXbTn7ZA3UxCdSg46dsktuvkBfQ1nb1xZBS9jtnZCQiVk5kyqW5KGJidZBPzZAwEvAbxFpSI5J0dLOufCmOKCxuB075PfoZBCBhWNNB4kMLHDUldqI1xWVEycNgoTKZArRwZAuUfSa2BjwscwZD")

# %%
graph

# %%
ba_statuses = graph.get_object("britishairways",fields='statuses')

# %%
ba_statuses.keys()
# Out:
# ['paging', 'data']

# %%
sts = ba_statuses['statuses']

# %%
sts.keys()
# Out:
# ['paging', 'data']

# %%
data = sts['data']

# %%
for i,e in enumerate(data):
    print i,e['message']
    print "--------------------------",e["updated_time"]
# Out:
# 0 Flying to US or Europe for higher studies? Now you can earn enough bonus Avios to get an extra trip, absolutely free! All you have to do is enrol in the British Airways Executive Club programme.
# Learn more here http://bit.ly/1afykPd
# -------------------------- 2013-08-12T03:30:53+0000
# 1 Best of luck to British Airways ambassador Justin Rose at the US PGA this week! Send him your good luck messages here!
# -------------------------- 2013-08-08T07:00:33+0000
# 2 Planning to fly with your baby? We’ll do everything to make it a pleasant journey for you. Watch this video to find out how: http://goo.gl/JpXdoz
# -------------------------- 2013-08-01T03:30:07+0000
# 3 Claire our Destination Manager for European Beaches will be answering your questions tomorrow Friday 7th June (10am-3pm GMT).
# So tell us - what would you like to know about European beaches?
# -------------------------- 2013-06-06T09:53:44+0000
# ...
